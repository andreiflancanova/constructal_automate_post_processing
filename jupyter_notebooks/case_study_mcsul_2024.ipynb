# %%
import mysql.connector
from mysql.connector import Error

def retrieve_plate():
    try:
        print("Trying to connect to database.")
        connection = mysql.connector.connect(
            host='localhost',
            port=3306,
            database='constructal_automate_mcsul_2024_results',
            user='constructal_automate',
            password='constructal_design_2024'
        )
        
        if connection.is_connected():
            print("Connected to database successfully.")
            cursor = connection.cursor()
            
            # Query SQL
            query = """
                SELECT id FROM csg_stiffenedplate sp
                WHERE sp.phi = 0.3
                  AND sp.N_ts = 2
                  AND sp.N_ls = 2
                  and sp.id != 2
            """
            
            # Executa a query
            cursor.execute(query)
            
            # Busca todos os resultados
            results = cursor.fetchall()
            
            # Extrai os ids para a lista stiffened_plates_to_analyse
            plates_to_analyse = [row[0] for row in results]
            
            print(f" {len(plates_to_analyse)} Found IDs: {plates_to_analyse}")
            return plates_to_analyse
            
    except Error as e:
        print(f"Unable to connect to database: {e}")
    finally:
        if connection.is_connected():
            cursor.close()
            connection.close()
            print("Database connection closed.")

# Chama a função
plates_to_analyse = retrieve_plate()
# Out:
# Trying to connect to database.
# Connected to database successfully.
#  8 Found IDs: [14, 15, 16, 17, 18, 19, 20, 21]
# Database connection closed.

# %%
import requests
from requests.auth import HTTPBasicAuth
import time
import pandas as pd

# Configurações da API
STIFFENED_PLATE_ANALYSIS_BASE_URL = 'http://127.0.0.1:8000/stiffened-plate-analysis/'
ELASTIC_BUCKLING_BASE_URL = 'http://127.0.0.1:8000/elastic-buckling/'
ELASTO_PLASTIC_BUCKLING_BASE_URL = 'http://127.0.0.1:8000/elasto-plastic-buckling/'
USERNAME = 'andreiflancanova'
PASSWORD = 'teste1234'

# Função genérica para fazer uma requisição POST e medir o tempo
def make_request(url, request_body, context):
    try:
        start_time = time.time()  # Medir tempo de início

        response = requests.post(url, json=request_body, auth=HTTPBasicAuth(USERNAME, PASSWORD))
        response_json = response.json()

        duration = time.time() - start_time  # Duração da requisição

        # Tratamento de erros de resposta HTTP
        if response.status_code == 201:
            id = response_json.get("id")
            print(f"{response_json}")
            print("\n")
            return id, duration
        elif response.status_code == 400:
            print(f"Erro de validação")
            print(f"Request Body: {request_body}")
            print(f"Status Code: {response.status_code}")
            print("Response: \n")
            print(f"{response_json}")
            return None, duration
        elif response.status_code == 401:
            print(f"{context}: Falha na autenticação. Verifique suas credenciais.")
            return None, duration
        else:
            print("Erro inesperado na requisição")
            print(f"Request Body: {request_body}")
            print(f"Status Code: {response.status_code}")
            print("Response: \n")
            print(f"{response_json}")
            return None, duration
    except requests.exceptions.RequestException as e:
        print(f"{context}: Erro de conexão ou de requisição: {e}")
        return None, None

# Funções específicas para cada tipo de requisição
def generate_stiffened_plate_analysis(mesh_size, buckling_load_type, case_study, material, stiffened_plate_id):
    request_body = {
        "mesh_size": mesh_size,
        "buckling_load_type": buckling_load_type,
        "case_study": case_study,
        "material": material,
        "stiffened_plate": stiffened_plate_id
    }
    return make_request(STIFFENED_PLATE_ANALYSIS_BASE_URL, request_body, "STIFFENED_PLATE_ANALYSIS")

def generate_elastic_buckling(stiffened_plate_analysis_id):
    request_body = {
        "stiffened_plate_analysis": stiffened_plate_analysis_id
    }
    return make_request(ELASTIC_BUCKLING_BASE_URL, request_body, "ELASTIC_BUCKLING")

def generate_elasto_plastic_buckling(stiffened_plate_analysis_id):
    request_body = {
        "stiffened_plate_analysis": stiffened_plate_analysis_id
    }
    return make_request(ELASTO_PLASTIC_BUCKLING_BASE_URL, request_body, "ELASTO_PLASTIC_BUCKLING")

# Função principal para realizar as três requisições em sequência e gerar a planilha
def execute_analises(mesh_size, buckling_load_type, case_study, material, stiffened_plate_id_list):
    for stiffened_plate_id in stiffened_plate_id_list:
        # Executar as três requisições e capturar tempos
        
        print("STIFFENED PLATE ANALYSIS")
        id_spa, elapsed_time_spa = generate_stiffened_plate_analysis(mesh_size, buckling_load_type, case_study, material, stiffened_plate_id)
        
        print("ELASTIC BUCKLING")
        id_eb, elapsed_time_eb = generate_elastic_buckling(id_spa)
        
        print("ELASTO-PLASTIC BUCKLING")
        id_epb, elapsed_time_epb = generate_elasto_plastic_buckling(id_spa)

# %%
#mesh_size_list = [100, 75, 50, 40, 25, 20, 15, 10]
mesh_size = 25
buckling_load_type = 2
case_study = 'ec_1a_2_2_lima_2020_phi_0.3'
material = 1

# %%
print(plates_to_analyse)
# Out:
# [14, 15, 16, 17, 18, 19, 20, 21]

# %%
execute_analises(mesh_size, buckling_load_type, case_study, material, plates_to_analyse)
# Out:
# STIFFENED PLATE ANALYSIS
# {'id': 74, 'mesh_size': '25.0', 'num_elem': 6354, 'case_study': 'ec_2a_2_2_lima_2020_phi_0.3', 'analysis_dir_path': 'D:/constructal_automate_analysis_files/ec_2a_2_2_lima_2020_phi_0.3/BL2M1P0.3L2T2_k56.19_MS25_SP14', 'analysis_rst_file_path': None, 'analysis_lgw_file_path': 'D:/constructal_automate_analysis_files/ec_2a_2_2_lima_2020_phi_0.3/BL2M1P0.3L2T2_k56.19_MS25_SP14/BL2M1P0.3L2T2_k56.19_MS25_SP14.txt', 'material': 1, 'stiffened_plate': 14, 'buckling_load_type': 2, 'elastic_buckling_status': 1, 'elasto_plastic_buckling_status': 1}
#
#
# ELASTIC BUCKLING
# {'id': 74, 'n_cr': '309.27', 'sigma_cr': '31.56', 'w_center': '0.0142', 'stiffened_plate_analysis': 74}
#
#
# ELASTO-PLASTIC BUCKLING
# {'id': 74, 'p_u': '3479.00', 'n_u': '250.54', 'sigma_u': '25.57', 'w_max': '0.1573', 'w_dist_img_path': 'D:/constructal_automate_analysis_files/ec_2a_2_2_lima_2020_phi_0.3/BL2M1P0.3L2T2_k56.19_MS25_SP14/BL2M1P0.3L2T2_k56.19_MS25_SP14_w_dist.png', 'von_mises_dist_img_path': 'D:/constructal_automate_analysis_files/ec_2a_2_2_lima_2020_phi_0.3/BL2M1P0.3L2T2_k56.19_MS25_SP14/BL2M1P0.3L2T2_k56.19_MS25_SP14_von_mises_dist.png', 'stiffened_plate_analysis': 74}
#
#
# STIFFENED PLATE ANALYSIS
# {'id': 75, 'mesh_size': '25.0', 'num_elem': 4878, 'case_study': 'ec_2a_2_2_lima_2020_phi_0.3', 'analysis_dir_path': 'D:/constructal_automate_analysis_files/ec_2a_2_2_lima_2020_phi_0.3/BL2M1P0.3L2T2_k14.09_MS25_SP15', 'analysis_rst_file_path': None, 'analysis_lgw_file_path': 'D:/constructal_automate_analysis_files/ec_2a_2_2_lima_2020_phi_0.3/BL2M1P0.3L2T2_k14.09_MS25_SP15/BL2M1P0.3L2T2_k14.09_MS25_SP15.txt', 'material': 1, 'stiffened_plate': 15, 'buckling_load_type': 2, 'elastic_buckling_status': 1, 'elasto_plastic_buckling_status': 1}
#
#
# ELASTIC BUCKLING
# {'id': 75, 'n_cr': '2164.44', 'sigma_cr': '220.86', 'w_center': '0.8764', 'stiffened_plate_analysis': 75}
#
#
# ELASTO-PLASTIC BUCKLING
# {'id': 75, 'p_u': '3479.00', 'n_u': '1922.58', 'sigma_u': '196.18', 'w_max': '3.6033', 'w_dist_img_path': 'D:/constructal_automate_analysis_files/ec_2a_2_2_lima_2020_phi_0.3/BL2M1P0.3L2T2_k14.09_MS25_SP15/BL2M1P0.3L2T2_k14.09_MS25_SP15_w_dist.png', 'von_mises_dist_img_path': 'D:/constructal_automate_analysis_files/ec_2a_2_2_lima_2020_phi_0.3/BL2M1P0.3L2T2_k14.09_MS25_SP15/BL2M1P0.3L2T2_k14.09_MS25_SP15_von_mises_dist.png', 'stiffened_plate_analysis': 75}
#
#
# STIFFENED PLATE ANALYSIS
# {'id': 76, 'mesh_size': '25.0', 'num_elem': 4386, 'case_study': 'ec_2a_2_2_lima_2020_phi_0.3', 'analysis_dir_path': 'D:/constructal_automate_analysis_files/ec_2a_2_2_lima_2020_phi_0.3/BL2M1P0.3L2T2_k6.29_MS25_SP16', 'analysis_rst_file_path': None, 'analysis_lgw_file_path': 'D:/constructal_automate_analysis_files/ec_2a_2_2_lima_2020_phi_0.3/BL2M1P0.3L2T2_k6.29_MS25_SP16/BL2M1P0.3L2T2_k6.29_MS25_SP16.txt', 'material': 1, 'stiffened_plate': 16, 'buckling_load_type': 2, 'elastic_buckling_status': 1, 'elasto_plastic_buckling_status': 1}
#
#
# ELASTIC BUCKLING
# {'id': 76, 'n_cr': '2437.49', 'sigma_cr': '248.72', 'w_center': '1.0000', 'stiffened_plate_analysis': 76}
#
#
# ELASTO-PLASTIC BUCKLING
# {'id': 76, 'p_u': '3479.00', 'n_u': '2072.18', 'sigma_u': '211.45', 'w_max': '3.4895', 'w_dist_img_path': 'D:/constructal_automate_analysis_files/ec_2a_2_2_lima_2020_phi_0.3/BL2M1P0.3L2T2_k6.29_MS25_SP16/BL2M1P0.3L2T2_k6.29_MS25_SP16_w_dist.png', 'von_mises_dist_img_path': 'D:/constructal_automate_analysis_files/ec_2a_2_2_lima_2020_phi_0.3/BL2M1P0.3L2T2_k6.29_MS25_SP16/BL2M1P0.3L2T2_k6.29_MS25_SP16_von_mises_dist.png', 'stiffened_plate_analysis': 76}
#
#
# STIFFENED PLATE ANALYSIS
# {'id': 77, 'mesh_size': '25.0', 'num_elem': 4386, 'case_study': 'ec_2a_2_2_lima_2020_phi_0.3', 'analysis_dir_path': 'D:/constructal_automate_analysis_files/ec_2a_2_2_lima_2020_phi_0.3/BL2M1P0.3L2T2_k3.55_MS25_SP17', 'analysis_rst_file_path': None, 'analysis_lgw_file_path': 'D:/constructal_automate_analysis_files/ec_2a_2_2_lima_2020_phi_0.3/BL2M1P0.3L2T2_k3.55_MS25_SP17/BL2M1P0.3L2T2_k3.55_MS25_SP17.txt', 'material': 1, 'stiffened_plate': 17, 'buckling_load_type': 2, 'elastic_buckling_status': 1, 'elasto_plastic_buckling_status': 1}
#
#
# ELASTIC BUCKLING
# {'id': 77, 'n_cr': '2621.94', 'sigma_cr': '267.55', 'w_center': '1.0000', 'stiffened_plate_analysis': 77}
#
#
# ELASTO-PLASTIC BUCKLING
# {'id': 77, 'p_u': '3479.00', 'n_u': '2146.98', 'sigma_u': '219.08', 'w_max': '3.1459', 'w_dist_img_path': 'D:/constructal_automate_analysis_files/ec_2a_2_2_lima_2020_phi_0.3/BL2M1P0.3L2T2_k3.55_MS25_SP17/BL2M1P0.3L2T2_k3.55_MS25_SP17_w_dist.png', 'von_mises_dist_img_path': 'D:/constructal_automate_analysis_files/ec_2a_2_2_lima_2020_phi_0.3/BL2M1P0.3L2T2_k3.55_MS25_SP17/BL2M1P0.3L2T2_k3.55_MS25_SP17_von_mises_dist.png', 'stiffened_plate_analysis': 77}
#
#
# STIFFENED PLATE ANALYSIS
# {'id': 78, 'mesh_size': '25.0', 'num_elem': 4140, 'case_study': 'ec_2a_2_2_lima_2020_phi_0.3', 'analysis_dir_path': 'D:/constructal_automate_analysis_files/ec_2a_2_2_lima_2020_phi_0.3/BL2M1P0.3L2T2_k2.28_MS25_SP18', 'analysis_rst_file_path': None, 'analysis_lgw_file_path': 'D:/constructal_automate_analysis_files/ec_2a_2_2_lima_2020_phi_0.3/BL2M1P0.3L2T2_k2.28_MS25_SP18/BL2M1P0.3L2T2_k2.28_MS25_SP18.txt', 'material': 1, 'stiffened_plate': 18, 'buckling_load_type': 2, 'elastic_buckling_status': 1, 'elasto_plastic_buckling_status': 1}
#
#
# ELASTIC BUCKLING
# {'id': 78, 'n_cr': '2741.96', 'sigma_cr': '279.79', 'w_center': '1.0000', 'stiffened_plate_analysis': 78}
#
#
# ELASTO-PLASTIC BUCKLING
# {'id': 78, 'p_u': '3479.00', 'n_u': '2169.59', 'sigma_u': '221.39', 'w_max': '3.4031', 'w_dist_img_path': 'D:/constructal_automate_analysis_files/ec_2a_2_2_lima_2020_phi_0.3/BL2M1P0.3L2T2_k2.28_MS25_SP18/BL2M1P0.3L2T2_k2.28_MS25_SP18_w_dist.png', 'von_mises_dist_img_path': 'D:/constructal_automate_analysis_files/ec_2a_2_2_lima_2020_phi_0.3/BL2M1P0.3L2T2_k2.28_MS25_SP18/BL2M1P0.3L2T2_k2.28_MS25_SP18_von_mises_dist.png', 'stiffened_plate_analysis': 78}
#
#
# STIFFENED PLATE ANALYSIS
# {'id': 79, 'mesh_size': '25.0', 'num_elem': 4140, 'case_study': 'ec_2a_2_2_lima_2020_phi_0.3', 'analysis_dir_path': 'D:/constructal_automate_analysis_files/ec_2a_2_2_lima_2020_phi_0.3/BL2M1P0.3L2T2_k1.59_MS25_SP19', 'analysis_rst_file_path': None, 'analysis_lgw_file_path': 'D:/constructal_automate_analysis_files/ec_2a_2_2_lima_2020_phi_0.3/BL2M1P0.3L2T2_k1.59_MS25_SP19/BL2M1P0.3L2T2_k1.59_MS25_SP19.txt', 'material': 1, 'stiffened_plate': 19, 'buckling_load_type': 2, 'elastic_buckling_status': 1, 'elasto_plastic_buckling_status': 1}
#
#
# ELASTIC BUCKLING
# {'id': 79, 'n_cr': '2810.87', 'sigma_cr': '286.82', 'w_center': '1.0000', 'stiffened_plate_analysis': 79}
#
#
# ELASTO-PLASTIC BUCKLING
# {'id': 79, 'p_u': '3479.00', 'n_u': '2143.85', 'sigma_u': '218.76', 'w_max': '7.6305', 'w_dist_img_path': 'D:/constructal_automate_analysis_files/ec_2a_2_2_lima_2020_phi_0.3/BL2M1P0.3L2T2_k1.59_MS25_SP19/BL2M1P0.3L2T2_k1.59_MS25_SP19_w_dist.png', 'von_mises_dist_img_path': 'D:/constructal_automate_analysis_files/ec_2a_2_2_lima_2020_phi_0.3/BL2M1P0.3L2T2_k1.59_MS25_SP19/BL2M1P0.3L2T2_k1.59_MS25_SP19_von_mises_dist.png', 'stiffened_plate_analysis': 79}
#
#
# STIFFENED PLATE ANALYSIS
# {'id': 80, 'mesh_size': '25.0', 'num_elem': 3894, 'case_study': 'ec_2a_2_2_lima_2020_phi_0.3', 'analysis_dir_path': 'D:/constructal_automate_analysis_files/ec_2a_2_2_lima_2020_phi_0.3/BL2M1P0.3L2T2_k1.17_MS25_SP20', 'analysis_rst_file_path': None, 'analysis_lgw_file_path': 'D:/constructal_automate_analysis_files/ec_2a_2_2_lima_2020_phi_0.3/BL2M1P0.3L2T2_k1.17_MS25_SP20/BL2M1P0.3L2T2_k1.17_MS25_SP20.txt', 'material': 1, 'stiffened_plate': 20, 'buckling_load_type': 2, 'elastic_buckling_status': 1, 'elasto_plastic_buckling_status': 1}
#
#
# ELASTIC BUCKLING
# {'id': 80, 'n_cr': '2346.72', 'sigma_cr': '239.46', 'w_center': '1.0000', 'stiffened_plate_analysis': 80}
#
#
# ELASTO-PLASTIC BUCKLING
# {'id': 80, 'p_u': '3479.00', 'n_u': '1778.38', 'sigma_u': '181.47', 'w_max': '9.8215', 'w_dist_img_path': 'D:/constructal_automate_analysis_files/ec_2a_2_2_lima_2020_phi_0.3/BL2M1P0.3L2T2_k1.17_MS25_SP20/BL2M1P0.3L2T2_k1.17_MS25_SP20_w_dist.png', 'von_mises_dist_img_path': 'D:/constructal_automate_analysis_files/ec_2a_2_2_lima_2020_phi_0.3/BL2M1P0.3L2T2_k1.17_MS25_SP20/BL2M1P0.3L2T2_k1.17_MS25_SP20_von_mises_dist.png', 'stiffened_plate_analysis': 80}
#
#
# STIFFENED PLATE ANALYSIS
# {'id': 81, 'mesh_size': '25.0', 'num_elem': 3894, 'case_study': 'ec_2a_2_2_lima_2020_phi_0.3', 'analysis_dir_path': 'D:/constructal_automate_analysis_files/ec_2a_2_2_lima_2020_phi_0.3/BL2M1P0.3L2T2_k0.9_MS25_SP21', 'analysis_rst_file_path': None, 'analysis_lgw_file_path': 'D:/constructal_automate_analysis_files/ec_2a_2_2_lima_2020_phi_0.3/BL2M1P0.3L2T2_k0.9_MS25_SP21/BL2M1P0.3L2T2_k0.9_MS25_SP21.txt', 'material': 1, 'stiffened_plate': 21, 'buckling_load_type': 2, 'elastic_buckling_status': 1, 'elasto_plastic_buckling_status': 1}
#
#
# ELASTIC BUCKLING
# {'id': 81, 'n_cr': '1986.17', 'sigma_cr': '202.67', 'w_center': '1.0000', 'stiffened_plate_analysis': 81}
#
#
# ELASTO-PLASTIC BUCKLING
# {'id': 81, 'p_u': '3479.00', 'n_u': '1512.23', 'sigma_u': '154.31', 'w_max': '9.7893', 'w_dist_img_path': 'D:/constructal_automate_analysis_files/ec_2a_2_2_lima_2020_phi_0.3/BL2M1P0.3L2T2_k0.9_MS25_SP21/BL2M1P0.3L2T2_k0.9_MS25_SP21_w_dist.png', 'von_mises_dist_img_path': 'D:/constructal_automate_analysis_files/ec_2a_2_2_lima_2020_phi_0.3/BL2M1P0.3L2T2_k0.9_MS25_SP21/BL2M1P0.3L2T2_k0.9_MS25_SP21_von_mises_dist.png', 'stiffened_plate_analysis': 81}

# %%
#mesh_size_list = [100, 75, 50, 40, 25, 20, 15, 10]

#Placa de referência
plates_to_analyse = [22]
mesh_size = 25
buckling_load_type = 1
case_study = 'ec_1a_2_2_lima_2020_ref'
material = 1

# %%
execute_analises(mesh_size, buckling_load_type, case_study, material, plates_to_analyse)
# Out:
# STIFFENED PLATE ANALYSIS
# {'id': 82, 'mesh_size': '25.0', 'num_elem': 3200, 'case_study': 'ec_1a_2_2_lima_2020_ref', 'analysis_dir_path': 'D:/constructal_automate_analysis_files/ec_1a_2_2_lima_2020_ref/BL1M1P0L0T0_k0_MS25_SP22', 'analysis_rst_file_path': None, 'analysis_lgw_file_path': 'D:/constructal_automate_analysis_files/ec_1a_2_2_lima_2020_ref/BL1M1P0L0T0_k0_MS25_SP22/BL1M1P0L0T0_k0_MS25_SP22.txt', 'material': 1, 'stiffened_plate': 22, 'buckling_load_type': 1, 'elastic_buckling_status': 1, 'elasto_plastic_buckling_status': 1}
#
#
# ELASTIC BUCKLING
# {'id': 82, 'n_cr': '2061.66', 'sigma_cr': '147.26', 'w_center': '1.0000', 'stiffened_plate_analysis': 82}
#
#
# ELASTO-PLASTIC BUCKLING
# {'id': 82, 'p_u': '4970.00', 'n_u': '2610.37', 'sigma_u': '186.45', 'w_max': '18.1141', 'w_dist_img_path': 'D:/constructal_automate_analysis_files/ec_1a_2_2_lima_2020_ref/BL1M1P0L0T0_k0_MS25_SP22/BL1M1P0L0T0_k0_MS25_SP22_w_dist.png', 'von_mises_dist_img_path': 'D:/constructal_automate_analysis_files/ec_1a_2_2_lima_2020_ref/BL1M1P0L0T0_k0_MS25_SP22/BL1M1P0L0T0_k0_MS25_SP22_von_mises_dist.png', 'stiffened_plate_analysis': 82}

# %%
#mesh_size_list = [100, 75, 50, 40, 25, 20, 15, 10]

#Placa de referência
plates_to_analyse = [22]
mesh_size = 25
buckling_load_type = 2
case_study = 'ec_2a_2_2_lima_2020_ref'
material = 1

# %%
execute_analises(mesh_size, buckling_load_type, case_study, material, plates_to_analyse)
# Out:
# STIFFENED PLATE ANALYSIS
# {'id': 83, 'mesh_size': '25.0', 'num_elem': 3200, 'case_study': 'ec_2a_2_2_lima_2020_ref', 'analysis_dir_path': 'D:/constructal_automate_analysis_files/ec_2a_2_2_lima_2020_ref/BL2M1P0L0T0_k0_MS25_SP22', 'analysis_rst_file_path': None, 'analysis_lgw_file_path': 'D:/constructal_automate_analysis_files/ec_2a_2_2_lima_2020_ref/BL2M1P0L0T0_k0_MS25_SP22/BL2M1P0L0T0_k0_MS25_SP22.txt', 'material': 1, 'stiffened_plate': 22, 'buckling_load_type': 2, 'elastic_buckling_status': 1, 'elasto_plastic_buckling_status': 1}
#
#
# ELASTIC BUCKLING
# {'id': 83, 'n_cr': '646.71', 'sigma_cr': '46.19', 'w_center': '1.0000', 'stiffened_plate_analysis': 83}
#
#
# ELASTO-PLASTIC BUCKLING
# {'id': 83, 'p_u': '4970.00', 'n_u': '835.58', 'sigma_u': '59.68', 'w_max': '38.0533', 'w_dist_img_path': 'D:/constructal_automate_analysis_files/ec_2a_2_2_lima_2020_ref/BL2M1P0L0T0_k0_MS25_SP22/BL2M1P0L0T0_k0_MS25_SP22_w_dist.png', 'von_mises_dist_img_path': 'D:/constructal_automate_analysis_files/ec_2a_2_2_lima_2020_ref/BL2M1P0L0T0_k0_MS25_SP22/BL2M1P0L0T0_k0_MS25_SP22_von_mises_dist.png', 'stiffened_plate_analysis': 83}

# %%
import mysql.connector
import matplotlib.pyplot as plt
from datetime import datetime
from scipy.interpolate import make_interp_spline, BSpline
import numpy as np
from decimal import Decimal
from matplotlib.ticker import AutoMinorLocator, FuncFormatter,MultipleLocator
import matplotlib.ticker as ticker
import locale
locale.setlocale(locale.LC_NUMERIC, 'pt_BR.UTF-8')

# 1. Conectar ao banco de dados MySQL
con = mysql.connector.connect(
    host="localhost",        
    user="constructal_automate",     
    password="constructal_design_2024",    
    database="constructal_automate_mcsul_2024_results"
)

cur = con.cursor()

query = f'''
SELECT sp.k, epb.sigma_u FROM constructal_automate_mcsul_2024_results.cbeb_elastoplasticbuckling as epb
INNER JOIN constructal_automate_mcsul_2024_results.cbeb_stiffenedplateanalysis as spa on epb.stiffened_plate_analysis_id=spa.id
INNER JOIN constructal_automate_mcsul_2024_results.csg_stiffenedplate as sp on spa.stiffened_plate_id=sp.id
WHERE spa.id between 66 and 73;
'''
cur.execute(query)
dados_1a_sp = cur.fetchall()

query = f'''
SELECT sp.k, epb.sigma_u FROM constructal_automate_mcsul_2024_results.cbeb_elastoplasticbuckling as epb
INNER JOIN constructal_automate_mcsul_2024_results.cbeb_stiffenedplateanalysis as spa on epb.stiffened_plate_analysis_id=spa.id
INNER JOIN constructal_automate_mcsul_2024_results.csg_stiffenedplate as sp on spa.stiffened_plate_id=sp.id
WHERE spa.id between 74 and 81;
'''
cur.execute(query)
dados_2a_sp = cur.fetchall()

query = f'''
SELECT sp.k, epb.sigma_u FROM constructal_automate_mcsul_2024_results.cbeb_elastoplasticbuckling as epb
INNER JOIN constructal_automate_mcsul_2024_results.cbeb_stiffenedplateanalysis as spa on epb.stiffened_plate_analysis_id=spa.id
INNER JOIN constructal_automate_mcsul_2024_results.csg_stiffenedplate as sp on spa.stiffened_plate_id=sp.id
WHERE spa.id = 82;
'''
cur.execute(query)
dados_1a_ns = cur.fetchall()

query = f'''
SELECT sp.k, epb.sigma_u FROM constructal_automate_mcsul_2024_results.cbeb_elastoplasticbuckling as epb
INNER JOIN constructal_automate_mcsul_2024_results.cbeb_stiffenedplateanalysis as spa on epb.stiffened_plate_analysis_id=spa.id
INNER JOIN constructal_automate_mcsul_2024_results.csg_stiffenedplate as sp on spa.stiffened_plate_id=sp.id
WHERE spa.id = 83;
'''
cur.execute(query)
dados_2a_ns = cur.fetchall()

# Fechar a conexão com o banco de dados
con.close()

k_data = [row[0] for row in dados_1a_sp]
sigma_u_1a_ns_data = [row[1] for row in dados_1a_ns]*len(k_data)
sigma_u_1a_sp_data = [row[1] for row in dados_1a_sp]
nus_1a = [sigma_u_1a_sp_data/sigma_u_1a_ns_data for sigma_u_1a_sp_data, sigma_u_1a_ns_data in zip(sigma_u_1a_sp_data, sigma_u_1a_ns_data)]
sigma_u_2a_ns_data = [row[1] for row in dados_2a_ns]*len(k_data)
sigma_u_2a_sp_data = [row[1] for row in dados_2a_sp]
nus_2a = [sigma_u_2a_sp_data/sigma_u_2a_ns_data for sigma_u_2a_sp_data, sigma_u_2a_ns_data in zip(sigma_u_2a_sp_data, sigma_u_2a_ns_data)]

print(k_data)
print(sigma_u_1a_ns_data)
print(sigma_u_1a_sp_data)
print(sigma_u_2a_ns_data)
print(sigma_u_2a_sp_data)

print(nus_1a)
print(nus_2a)
# Out:
# [Decimal('56.190'), Decimal('14.090'), Decimal('6.290'), Decimal('3.550'), Decimal('2.280'), Decimal('1.590'), Decimal('1.170'), Decimal('0.900')]
# [Decimal('186.45'), Decimal('186.45'), Decimal('186.45'), Decimal('186.45'), Decimal('186.45'), Decimal('186.45'), Decimal('186.45'), Decimal('186.45')]
# [Decimal('31.03'), Decimal('352.90'), Decimal('325.67'), Decimal('312.65'), Decimal('304.75'), Decimal('299.41'), Decimal('296.56'), Decimal('291.85')]
# [Decimal('59.68'), Decimal('59.68'), Decimal('59.68'), Decimal('59.68'), Decimal('59.68'), Decimal('59.68'), Decimal('59.68'), Decimal('59.68')]
# [Decimal('25.57'), Decimal('196.18'), Decimal('211.45'), Decimal('219.08'), Decimal('221.39'), Decimal('218.76'), Decimal('181.47'), Decimal('154.31')]
# [Decimal('0.1664253150978814695628854921'), Decimal('1.892732636095467953875033521'), Decimal('1.746688120139447573075891660'), Decimal('1.676857066237597211048538482'), Decimal('1.634486457495307052829176723'), Decimal('1.605846071332796996513810673'), Decimal('1.590560471976401179941002950'), Decimal('1.565299007776883883078573344')]
# [Decimal('0.4284517426273458445040214477'), Decimal('3.287198391420911528150134048'), Decimal('3.543063002680965147453083110'), Decimal('3.670911528150134048257372654'), Decimal('3.709617962466487935656836461'), Decimal('3.665549597855227882037533512'), Decimal('3.040717158176943699731903485'), Decimal('2.585623324396782841823056300')]

# %%
plt.rcParams['axes.formatter.use_locale'] = True

min_k = 0
max_k = 60

min_sigma_u = 0
max_sigma_u = 240
          
# Criar o gráfico
fig, ax = plt.subplots(figsize=(8, 6))

# ax.plot(k_data, sigma_u_1a_data, '-o', color='#2b5a74', lw=2, markersize=4, label=r'$\sigma_{u,1A}$ | Reproduzido de Lima et al. (2020)')
ax.plot(k_data, sigma_u_2a_sp_data, '-o', color='#d84528', lw=2, markersize=4, label=r'$\sigma_{u,2A}$')
ax.plot(k_data, sigma_u_2a_ns_data, color='#eb8e27', lw=2, linestyle='--', marker='', label=r'$\sigma_{uR,2A}$ = 59.68MPa')

ax.xaxis.set_major_formatter(ticker.FuncFormatter(lambda x, _: f'{x:,.1f}'.replace('.', ',')))
ax.yaxis.set_major_formatter(ticker.FuncFormatter(lambda y, _: f'{y:,.1f}'.replace('.', ',')))

# Configurar rótulos dos eixos e legenda
ax.set_xlabel(r'Relação de lados dos enrijecedores', fontsize=12)
# ax.set_ylabel(r'$\sigma_{u,1A}$', fontsize=12)
ax.set_ylabel('Tensão Última de Flambagem Biaxial (MPa)', fontsize=12)
ax.legend(loc='lower left')

# Adicionar a malha ao gráfico
ax.grid(True)

# Definir os limites dos eixos, se necessário
ax.set_xlim([min_k, max_k])  # Limites do eixo X
ax.set_ylim([min_sigma_u, max_sigma_u])  # Limites do eixo Y

# ax.grid(True, linestyle='--', linewidth=0.5, which='major')  # Grade principal
# ax.grid(True, linestyle=':', linewidth=0.3, which='minor')   # Grade secundária

ax.yaxis.set_major_locator(MultipleLocator(60))
ax.xaxis.set_minor_locator(AutoMinorLocator(5))
ax.yaxis.set_minor_locator(AutoMinorLocator(6))
ax.yaxis.set_major_formatter(FuncFormatter(lambda x, _: f"{x:.2f}"))

# Salvar o gráfico com o timestamp e valores de N_ls e N_ts no nome do arquivo
plt.savefig(f'resultados_artigo_mcsul2024/ec-sigma-u-2a.png')

# Exibir o gráfico
plt.show()

# %%
plt.rcParams['axes.formatter.use_locale'] = True
plt.rcParams['font.family'] = 'Times New Roman'

min_k = 0
max_k = 60

min_sigma_u = 0
max_sigma_u = 360
          
# Criar o gráfico
fig, ax = plt.subplots(figsize=(10, 6))

# ax.plot(k_data, sigma_u_1a_ns_data, color='#45b6fe', lw=2, linestyle='--', marker='', label=r' Presente Estudo - Sem Enrijecedores - Uniaxial')
# ax.plot(k_data, sigma_u_1a_sp_data, '-o', color='#2b5a74', lw=2, markersize=4, label=r' Presente Estudo - Com Enrijecedores - Uniaxial')
# ax.plot(k_data, sigma_u_2a_ns_data, color='#eb8e27', lw=2, linestyle='--', marker='', label=r' Presente Estudo - Sem Enrijecedores - Biaxial')
# ax.plot(k_data, sigma_u_2a_sp_data, '-o', color='#d84528', lw=2, markersize=4, label=r' Presente Estudo - Com Enrijecedores - Biaxial')

ax.plot(k_data, sigma_u_1a_ns_data, color='#45b6fe', lw=2, linestyle='--', marker='', label=r'$\sigma_{uR,1A}$')
ax.plot(k_data, sigma_u_1a_sp_data, '-o', color='#2b5a74', lw=2, markersize=4, label=r'$\sigma_{u,1A}$')
ax.plot(k_data, sigma_u_2a_ns_data, color='#eb8e27', lw=2, linestyle='--', marker='', label=r'$\sigma_{uR,2A}$')
ax.plot(k_data, sigma_u_2a_sp_data, '-o', color='#d84528', lw=2, markersize=4, label=r'$\sigma_{u,2A}$')

# ax.plot(k_data, sigma_u_2a_sp_data, '-o', color='#d84528', lw=2, markersize=4, label=r'$\sigma_{u,2A}$ | Presente Estudo - Biaxial')

ax.xaxis.set_major_formatter(ticker.FuncFormatter(lambda x, _: f'{x:,.1f}'.replace('.', ',')))
ax.yaxis.set_major_formatter(ticker.FuncFormatter(lambda y, _: f'{y:,.2f}'.replace('.', ',')))

# Configurar rótulos dos eixos e legenda
ax.set_xlabel(r'Relação de lados dos enrijecedores', fontsize=22)
# ax.set_ylabel(r'$\sigma_{u,1A}$', fontsize=12)
ax.set_ylabel('Tensão Última de Flambagem (MPa)', fontsize=22)
ax.legend(loc='upper right',fontsize=14) #14 aqui equivale a 10 no word

# Adicionar a malha ao gráfico
ax.grid(True)

# Definir os limites dos eixos, se necessário
ax.set_xlim([min_k, max_k])  # Limites do eixo X
ax.set_ylim([min_sigma_u, max_sigma_u])  # Limites do eixo Y
ax.tick_params(axis='both', labelsize=18) #18 aqui equivale a 12 no word

# ax.grid(True, linestyle='--', linewidth=0.5, which='major')  # Grade principal
# ax.grid(True, linestyle=':', linewidth=0.3, which='minor')   # Grade secundária

ax.yaxis.set_major_locator(MultipleLocator(60))
ax.xaxis.set_minor_locator(AutoMinorLocator(5))
ax.yaxis.set_minor_locator(AutoMinorLocator(6))

# Salvar o gráfico com o timestamp e valores de N_ls e N_ts no nome do arquivo
plt.savefig(f'resultados_artigo_mcsul2024/ec-comparacao-sigma-u-1a-2a.png')

# Exibir o gráfico
plt.show()

# %%
plt.rcParams['axes.formatter.use_locale'] = True
plt.rcParams['font.family'] = 'Times New Roman'

min_k = 0
max_k = 60

min_sigma_u = 0
max_sigma_u = 4
          
# Criar o gráfico
fig, ax = plt.subplots(figsize=(10, 6))

ax.plot(k_data, nus_1a, '-o', color='#2b5a74', lw=2, markersize=4, label=r'$NUS_{1A}$')
ax.plot(k_data, nus_2a, '-o', color='#d84528', lw=2, markersize=4, label=r'$NUS_{2A}$')

ax.xaxis.set_major_formatter(ticker.FuncFormatter(lambda x, _: f'{x:,.1f}'.replace('.', ',')))
ax.yaxis.set_major_formatter(ticker.FuncFormatter(lambda y, _: f'{y:,.2f}'.replace('.', ',')))

# Configurar rótulos dos eixos e legenda
ax.set_xlabel(r'Relação de lados dos enrijecedores', fontsize=22)
# ax.set_ylabel(r'$\sigma_{u,1A}$', fontsize=12)
ax.set_ylabel('Tensão Última de Flambagem Normalizada', fontsize=22)
ax.legend(loc='upper right',fontsize=14)

# Adicionar a malha ao gráfico
ax.grid(True)
ax.tick_params(axis='both', labelsize=18) #18 aqui equivale a 12 no word

# Definir os limites dos eixos, se necessário
ax.set_xlim([min_k, max_k])  # Limites do eixo X
ax.set_ylim([min_sigma_u, max_sigma_u])  # Limites do eixo Y

# ax.grid(True, linestyle='--', linewidth=0.5, which='major')  # Grade principal
# ax.grid(True, linestyle=':', linewidth=0.3, which='minor')   # Grade secundária

ax.yaxis.set_major_locator(MultipleLocator(0.5))
ax.xaxis.set_minor_locator(AutoMinorLocator(5))
ax.yaxis.set_minor_locator(AutoMinorLocator(6))

# Salvar o gráfico com o timestamp e valores de N_ls e N_ts no nome do arquivo
plt.savefig(f'resultados_artigo_mcsul2024/ec-comparacao-nus-1a-2a.png')

# Exibir o gráfico
plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import AutoMinorLocator
from decimal import Decimal

# Dados de exemplo que você obtém da sua consulta SQL
# Suponha que 'elem_data' e 'sigma_u_data' já estejam preenchidos com dados do banco
# elem_data = [100, 500, 1000, 2000, 4000, 8000, 16000, 20000]  # Exemplo de dados
# sigma_u_data = [286.5, 286.8, 286.9, 286.95, 287, 287, 286.9, 286.85]  # Exemplo de dados

# Criar o gráfico
fig, ax = plt.subplots(figsize=(10, 6))

# Configurar a linha principal e os marcadores
ax.plot(elem_data, sigma_u_data, label='Flambagem elástica 1A - Placa de referência', color='red', marker='o', linestyle='-', markersize=5)
ax.set_xlabel(r'$h_{s}/t_{s}$', fontsize=14)
ax.set_ylabel(r'$\sigma_{u}$', fontsize=14)

# Adicionar rótulos aos marcadores com deslocamento
for x, y, label in zip(elem_data, sigma_u_data, labels):
    if x == elem_data[2]:
        ax.text(x + 100, y + Decimal(0.02), f'{label:.0f} mm', fontsize=8, ha='left', va='bottom')  # Ajuste de posição dos rótulos
    elif x == elem_data[-1]:
        ax.text(x - 1000, y - Decimal(0.01), f'{label:.0f} mm', fontsize=8, ha='left', va='top')  # Ajuste de posição dos rótulos
    else:
        ax.text(x + 100, y - Decimal(0.01), f'{label:.0f} mm', fontsize=8, ha='left', va='top')  # Ajuste de posição dos rótulos

# Configurações do gráfico
ax.legend(loc='lower right', fontsize=10)
ax.grid(True, linestyle='--', linewidth=0.5, which='major')  # Grade principal
ax.grid(True, linestyle=':', linewidth=0.3, which='minor')   # Grade secundária

ax.xaxis.set_minor_locator(AutoMinorLocator(5))  # Linhas secundárias em X (dividir em 4)
ax.yaxis.set_minor_locator(AutoMinorLocator(5))  # Linhas secundárias em Y (dividir em 4)

ax.set_xlim([0, 20000])  # Limites do eixo X
ax.set_ylim([285.7, 286.9])  # Limites do eixo Y

# Exibir o gráfico
plt.show()

# %%
import matplotlib.pyplot as plt

# Dados de exemplo
eixo_x =  [6.6, 2.934, 1.65, 1.08, 0.734, 0.543, 0.4, 0.312]
eixo_y_andrei = [121.28,140.06,139.38,121.99,108.61,104.70,100.91,98.83]
eixo_y_lima = [230.13,310.92,326.47,329.60,320.93,310.91,304.42,293.78]

# Criando a figura
fig, ax = plt.subplots(figsize=(10, 6))

# Plotando as linhas com estilos e rótulos
ax.plot(eixo_x, eixo_y_andrei, '-o', color='blue', lw=2.5, markersize=8, label=r'$\sigma_{u}$')
ax.plot(eixo_x, eixo_y_lima, '-o', color='orange', lw=1.5, markersize=6, label=r'$b2f2a=f=0.60$')
# ax.plot(eixo_x, tensao_b2f2a_eq_1_00, '-o', color='gray', lw=1.5, markersize=6, label=r'$b2f2a=f=1.00$')

# Adicionando anotações para cada ponto específico
labels = ['200 mm', '100 mm', '50 mm', '20 mm', '10 mm']
for i, txt in enumerate(labels):
    ax.annotate(txt, (eixo_x[i], eixo_y_andrei[i]), textcoords="offset points", xytext=(0,6), ha='center', color='blue', fontsize=9)
    ax.annotate(txt, (eixo_x[i], eixo_y_lima[i]), textcoords="offset points", xytext=(0,5), ha='center', color='orange', fontsize=9)
#     ax.annotate(txt, (num_elementos[i], tensao_b2f2a_eq_1_00[i]), textcoords="offset points", xytext=(0,5), ha='center', color='gray', fontsize=9)

# Configurações dos eixos
ax.set_xlabel('Número de Elementos Finitos', fontsize=12)
ax.set_ylabel('Tensão Última de Flambagem', fontsize=12)
ax.set_ylim(75, 350)
ax.set_xlim(0, 7)

# Exibindo a legenda na parte inferior
plt.legend(loc="upper center", bbox_to_anchor=(0.5, -0.1), ncol=3, fontsize=10)

# Adicionando a grade
plt.grid(True)

# Exibindo o gráfico
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Dados de exemplo
eixo_x =  [6.6, 2.934, 1.65, 1.08, 0.734, 0.543, 0.4, 0.312]
eixo_y_andrei = [121.28,140.06,139.38,121.99,108.61,104.70,100.91,98.83]
eixo_y_lima = [230.13,310.92,326.47,329.60,320.93,310.91,304.42,293.78]

# Criando a figura
fig, ax = plt.subplots(figsize=(10, 6))

# Plotando as linhas com estilos e rótulos
ax.plot(eixo_x, eixo_y_andrei, '-o', color='blue', lw=2.5, markersize=6, label=r'$\sigma_{u}$')
ax.plot(eixo_x, eixo_y_lima, '-o', color='#e65100', lw=2.5, markersize=6, label=r'$b2f2a=f=0.60$')
# ax.plot(eixo_x, tensao_b2f2a_eq_1_00, '-o', color='gray', lw=1.5, markersize=6, label=r'$b2f2a=f=1.00$')

# Adicionando anotações para cada ponto específico
labels = ['200 mm', '100 mm', '50 mm', '20 mm', '10 mm']
for i, txt in enumerate(labels):
    ax.annotate(txt, (eixo_x[i], eixo_y_andrei[i]), textcoords="offset points", xytext=(0,9), ha='center', color='blue', fontsize=9)
    ax.annotate(txt, (eixo_x[i], eixo_y_lima[i]), textcoords="offset points", xytext=(0,9), ha='center', color='#e65100', fontsize=9)
#     ax.annotate(txt, (num_elementos[i], tensao_b2f2a_eq_1_00[i]), textcoords="offset points", xytext=(0,5), ha='center', color='gray', fontsize=9)

# Configurações dos eixos
ax.set_xlabel('Número de Elementos Finitos', fontsize=12)
ax.set_ylabel('Tensão Última de Flambagem Normalizada (NUS)', fontsize=12)
ax.set_ylim(98.5, 350)
ax.set_xlim(0, 7)

# Exibindo a legenda na parte inferior
plt.legend(loc="upper center", bbox_to_anchor=(0.5, -0.1), ncol=3, fontsize=10)

# Adicionando a grade
plt.grid(True)

# Exibindo o gráfico
plt.tight_layout()
plt.show()
